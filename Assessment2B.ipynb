# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
data_1 = pd.read_csv('/content/college_1.csv')
data_2 =pd.read_csv('/content/college_2.csv')

# %%
data_1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
data_2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
data_1.shape
# Out:
# (84, 7)

# %%
data_2.shape
# Out:
# (35, 9)

# %%
data = pd.concat([data_1, data_2], sort= False, axis= 0)

# %%
data.head(100)
# Out:
#                     Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0              A.Dharani    82.0   20.0              24500           24500
# 1            V.JEEVITHA     82.0   20.0              21740           21740
# 2            HEMAVATHI.R   100.0  100.0              19680           19680
# 3            Mugunthan S   100.0   47.0              10610           10610
# 4            Sathammai.S   100.0    8.0               8980            8980
# ..                   ...     ...    ...                ...             ...
# 11  Balaraman Muthupandi    -1.0    0.0               7670            8050
# 12              JPradhap   100.0    0.0               7340            8030
# 13         SRIRAMKUMAR B    -1.0    0.0               6400            7940
# 14             Praneetha    -1.0  100.0               7170            7730
# 15           Rahul Raj K    -1.0    0.0               6280            7640
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
expectations = data['CodeKata Score'] > 15000

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
expectations = pd.DataFrame(expectations)

# %%
expectations.columns = ['Exceeded']

# %%
expectations
# Out:
#     Exceeded
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
# ..       ...
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
#
# [119 rows x 1 columns]

# %%
data = pd.concat([data, expectations], axis = 1)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data.to_csv('expectations.csv')

# %%
pd.read_csv('expectations.csv')
# Out:
#      Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0             0      A.Dharani    82.0   20.0              24500
# 1             1    V.JEEVITHA     82.0   20.0              21740
# 2             2    HEMAVATHI.R   100.0  100.0              19680
# 3             3    Mugunthan S   100.0   47.0              10610
# 4             4    Sathammai.S   100.0    8.0               8980
# ..          ...            ...     ...    ...                ...
# 114          30  praveen raj j    24.0    0.0               2380
# 115          31     AMARNATH D    -1.0   12.0               1890
# 116          32           bala    32.0    0.0               1720
# 117          33           XY Z    -1.0   -1.0                  0
# 118          34      Hariharan    -1.0   -1.0                  0
#
#      CodeKata Score                                 Department  Rising  \
# 0             24500           Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached_expectations = (data['CodeKata Score'] > 10000) & (data['CodeKata Score'] < 15000)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
Reached_expectations = pd.DataFrame(Reached_expectations)

# %%
Reached_expectations.columns = ['Reached_expectations']

# %%
Reached_expectations
# Out:
#     Reached_expectations
# 0                  False
# 1                  False
# 2                  False
# 3                   True
# 4                  False
# ..                   ...
# 30                 False
# 31                 False
# 32                 False
# 33                 False
# 34                 False
#
# [119 rows x 1 columns]

# %%
data = pd.concat([data, Reached_expectations], axis = 1)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising', 'python_en', 'computational_thinking',
#        'Exceeded', 'Reached_expectations'],
#       dtype='object')

# %%
data = data.drop('Exceeded', axis = 1)

# %%
data.to_csv('Reached_expectations.csv')

# %%
pd.read_csv('Reached_expectations.csv')
# Out:
#      Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0             0      A.Dharani    82.0   20.0              24500
# 1             1    V.JEEVITHA     82.0   20.0              21740
# 2             2    HEMAVATHI.R   100.0  100.0              19680
# 3             3    Mugunthan S   100.0   47.0              10610
# 4             4    Sathammai.S   100.0    8.0               8980
# ..          ...            ...     ...    ...                ...
# 114          30  praveen raj j    24.0    0.0               2380
# 115          31     AMARNATH D    -1.0   12.0               1890
# 116          32           bala    32.0    0.0               1720
# 117          33           XY Z    -1.0   -1.0                  0
# 118          34      Hariharan    -1.0   -1.0                  0
#
#      CodeKata Score                                 Department  Rising  \
# 0             24500           Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs_Improvement = (data['CodeKata Score'] > 7000) & (data['CodeKata Score'] < 10000)

# %%
Needs_Improvement = pd.DataFrame(Needs_Improvement)

# %%
Needs_Improvement.columns = ['Needs_Improvement']

# %%
Needs_Improvement
# Out:
#     Needs_Improvement
# 0               False
# 1               False
# 2               False
# 3               False
# 4                True
# ..                ...
# 30              False
# 31              False
# 32              False
# 33              False
# 34              False
#
# [119 rows x 1 columns]

# %%
data = pd.concat([data, Needs_Improvement], axis = 1)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising', 'python_en', 'computational_thinking',
#        'Reached_expectations', 'Needs_Improvement'],
#       dtype='object')

# %%
data = data.drop('Reached_expectations', axis = 1)

# %%
data.to_csv('Needs_Improvement.csv')

# %%
pd.read_csv('Needs_Improvement.csv')
# Out:
#      Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0             0      A.Dharani    82.0   20.0              24500
# 1             1    V.JEEVITHA     82.0   20.0              21740
# 2             2    HEMAVATHI.R   100.0  100.0              19680
# 3             3    Mugunthan S   100.0   47.0              10610
# 4             4    Sathammai.S   100.0    8.0               8980
# ..          ...            ...     ...    ...                ...
# 114          30  praveen raj j    24.0    0.0               2380
# 115          31     AMARNATH D    -1.0   12.0               1890
# 116          32           bala    32.0    0.0               1720
# 117          33           XY Z    -1.0   -1.0                  0
# 118          34      Hariharan    -1.0   -1.0                  0
#
#      CodeKata Score                                 Department  Rising  \
# 0             24500           Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory = (data['CodeKata Score'] < 7000)

# %%
Unsatisfactory = pd.DataFrame(Unsatisfactory)

# %%
Unsatisfactory.columns = ['Unsatisfactory']

# %%
Unsatisfactory
# Out:
#     Unsatisfactory
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 30            True
# 31            True
# 32            True
# 33            True
# 34            True
#
# [119 rows x 1 columns]

# %%
data = pd.concat([data, Unsatisfactory], axis = 1)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising', 'python_en', 'computational_thinking',
#        'Needs_Improvement', 'Unsatisfactory'],
#       dtype='object')

# %%
data = data.drop('Needs_Improvement', axis = 1)

# %%
data.to_csv('Unsatisfactory.csv')

# %%
pd.read_csv('Unsatisfactory.csv')
# Out:
#      Unnamed: 0           Name  python  mysql  Previous Geekions  \
# 0             0      A.Dharani    82.0   20.0              24500
# 1             1    V.JEEVITHA     82.0   20.0              21740
# 2             2    HEMAVATHI.R   100.0  100.0              19680
# 3             3    Mugunthan S   100.0   47.0              10610
# 4             4    Sathammai.S   100.0    8.0               8980
# ..          ...            ...     ...    ...                ...
# 114          30  praveen raj j    24.0    0.0               2380
# 115          31     AMARNATH D    -1.0   12.0               1890
# 116          32           bala    32.0    0.0               1720
# 117          33           XY Z    -1.0   -1.0                  0
# 118          34      Hariharan    -1.0   -1.0                  0
#
#      CodeKata Score                                 Department  Rising  \
# 0             24500           Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data = data.drop('Unsatisfactory', axis =1)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data['Previous Geekions'].mean()
# Out:
# 3842.3529411764707

# %%
data['CodeKata Score'].mean()
# Out:
# 4051.764705882353

# %%
sns.regplot(data = data, x= data['Previous Geekions'], y = data['CodeKata Score'])

# %% [markdown]
# ###### No of students participated

# %%
data['Name'].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
data['python'] = data['python'].replace(-1, np.nan)
data['mysql'] = data['mysql'].replace(-1, np.nan)
data['python_en'] = data['python_en'].replace(-1, np.nan)
data['computational_thinking'] = data['computational_thinking'].replace(-1, np.nan)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D     NaN   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z     NaN    NaN                  0               0
# 34      Hariharan     NaN    NaN                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
print(data['python'].mean())
print(data['mysql'].mean())
print(data['python_en'].mean())
print(data['computational_thinking'].mean())
# Out:
# 70.59782608695652
# 23.918803418803417
# 32.53125
# 3.0

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
data.reset_index(inplace= True)

# %%
data.tail(40)
# Out:
#      index                    Name  python  mysql  Previous Geekions  \
# 79      79            KarthikeyanS    45.0    0.0                  0
# 80      80                BARATH.P    29.0    0.0                  0
# 81      81           N.Ajith kumar    82.0    0.0                  0
# 82      82            mohamed nabi     0.0    0.0                  0
# 83      83          yaser ahamed.A     0.0   27.0                  0
# 84       0           ASHOK KUMAR K   100.0   31.0              19400
# 85       1                 Chandru     0.0    0.0              14150
# 86       2       Ganesh Ramkumar R     NaN   24.0               8790
# 87       3         Bodipudi Harini     NaN   35.0              10040
# 88       4               VIINU V P     NaN   24.0               9150
# 89       5              Poojitha Y     0.0   35.0               7210
# 90       6  Gowtham Chandrasekaran     NaN    0.0               7250
# 91       7               Gowtham R     NaN    4.0               8650
# ...

# %%
data['Rising'].sort_values()
# Out:
# 0         0
# 70        0
# 69        0
# 68        0
# 67        0
#        ...
# 106    1830
# 93     1990
# 86     2000
# 102    2000
# 92     3140
# Name: Rising, Length: 119, dtype: int64

# %%
rising_stars_of_the_week = data.iloc[[92, 102, 86], :]
rising_stars_of_the_week
# Out:
#      index               Name  python  mysql  Previous Geekions  \
# 92       8           shifak N    58.0    0.0               5180
# 102     18     Narasimhan Y L     NaN    0.0               4800
# 86       2  Ganesh Ramkumar R     NaN   24.0               8790
#
#      CodeKata Score                              Department  Rising  \
# 92             8320  Electronics and Electrical Engineering    3140
# 102            6800        Computer Science and Engineering    2000
# 86            10790        Computer Science and Engineering    2000
#
#      python_en  computational_thinking
# 92         0.0                     0.0
# 102        NaN                     0.0
# 86        55.0                     6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
data['CodeKata Score'].sort_values()
# Out:
# 118        0
# 79         0
# 80         0
# 117        0
# 82         0
#        ...
# 85     14490
# 84     19400
# 2      19680
# 1      21740
# 0      24500
# Name: CodeKata Score, Length: 119, dtype: int64

# %%
Shining_stars_of_the_week = data.iloc[[0,1,2], :]
Shining_stars_of_the_week
# Out:
#    index         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      0    A.Dharani    82.0   20.0              24500           24500
# 1      1  V.JEEVITHA     82.0   20.0              21740           21740
# 2      2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
data['Department'].unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
department_data = data.groupby('Department')

# %%
department_data.mean()
# Out:
#                                                index     python      mysql  \
# Department
# Computer Science and Engineering           26.444444  85.822222  22.938525
# Electronics and Communication Engineering  37.589744  48.109375  27.108974
# Electronics and Electrical Engineering     55.823529  72.900000  20.117647
#
#                                            Previous Geekions  CodeKata Score  \
# Department
# Computer Science and Engineering                 4792.619048     5079.761905
# Electronics and Communication Engineering        2751.923077     2777.820513
# Electronics and Electrical Engineering           2822.352941     3164.705882
#
#                                                Rising  python_en  \
# Department
# Computer Science and Engineering           287.142857  25.789474
# Electronics and Communication Engineering   25.897436  43.875000
# Electronics and Electrical Engineering     342.352941  40.000000
#
# ...

# %%
plt.pie(department_data['CodeKata Score'].mean(), labels= ['Computer Science and Engineering', 'Electronics and Communication Engineering', 'Electronics and Electrical Engineering'])
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
department_data.size()
# Out:
# Department
# Computer Science and Engineering             63
# Electronics and Communication Engineering    39
# Electronics and Electrical Engineering       17
# dtype: int64

# %%
data.groupby(['Department'])['CodeKata Score'].sort
# Out:
# True

# %%
x = data.groupby(['Department'])['CodeKata Score'].max()
x
# Out:
# Department
# Computer Science and Engineering             24500
# Electronics and Communication Engineering    10040
# Electronics and Electrical Engineering       19400
# Name: CodeKata Score, dtype: int64

# %%
x.plot(kind= 'barh', color = 'g')
